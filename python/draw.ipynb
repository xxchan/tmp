# %%
import matplotlib.pyplot as plt
import numpy as np


# Define the data from the table
types = ['Built-in', 'WASM', 'External (Python)', 'External (Rust)']
throughput = [2.163, 1.955, 0.75, 2.012]
compute_cpu_usage = [790, 782, 244, 793]
function_server_cpu_usage = [None, None, 120, 26]

# Create a numpy array for the position of each group
ind = np.arange(len(types))

# Set the width of each bar
width = 0.35

# Create a bar plot
plt.bar(types, throughput)

# Add labels and title
plt.xlabel('Type')
plt.ylabel('Source Throughput (Mrows/s)')
# plt.title('Source Throughput and Related Information')

# Customize x-axis labels
plt.xticks(types, rotation=45)
plt.gca().yaxis.grid(True)  # Add horizontal gridlines

# Add annotations for extra information
for i, t in enumerate(types):
    # if function_server_cpu_usage[i] is not None:
    #     annotate = f"Compute CPU: {compute_cpu_usage[i]}%\n Function Server CPU: {function_server_cpu_usage[i]}"
    # else:
    #     annotate = f"Compute CPU: {compute_cpu_usage[i]}%"
    # plt.annotate(annotate, 
    #              xy=(t, throughput[i]), xytext=(0, 10), 
    #              textcoords='offset points', ha='center')
    pass

# add bar labels
for i, v in enumerate(throughput):
    plt.text(i, v, str(v), ha='center')
    

# Show the plot
# plt.tight_layout()
plt.show()
